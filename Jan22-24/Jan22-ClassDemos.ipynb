# %%
#importing pandas
import pandas as pd
#read in the bikes.csv file
df = pd.read_csv('bikes.csv')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-4f781dfa6964> in <module>()
#       2 import pandas as pd
#       3 #read in the bikes.csv file
# ----> 4 df = pd.read_csv('bikes.csv')
#       5 df
#
# ...

# %%
import pandas as pd

#fix the data-set by using the correct encoding type
fixed_df = pd.read_csv('bikes.csv', sep=';', encoding='latin-1', index_col='Date')
#print only view the top 3 rows
fixed_df[:3]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 01/01/2012       35                                NaN                      0
# 02/01/2012       83                                NaN                      1
# 03/01/2012      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 01/01/2012             38             51       26            10       16
# 02/01/2012             68            153       53             6       43
# 03/01/2012            104            248       89             3       58
#
#             St-Urbain (données non disponibles)
# Date
# 01/01/2012                                  NaN
# 02/01/2012                                  NaN
# 03/01/2012                                  NaN

# %%
#print only the data from the 'Berri 1' column
fixed_df['Berri 1']
# Out:
# Date
# 01/01/2012      35
# 02/01/2012      83
# 03/01/2012     135
# 04/01/2012     144
# 05/01/2012     197
# 06/01/2012     146
# 07/01/2012      98
# 08/01/2012      95
# 09/01/2012     244
# 10/01/2012     397
# 11/01/2012     273
# 12/01/2012     157
# 13/01/2012      75
# 14/01/2012      32
# 15/01/2012      54
# 16/01/2012     168
# 17/01/2012     155
# 18/01/2012     139
# 19/01/2012     191
# 20/01/2012     161
# 21/01/2012      53
# 22/01/2012      71
# 23/01/2012     210
# 24/01/2012     299
# 25/01/2012     334
# 26/01/2012     306
# 27/01/2012      91
# 28/01/2012      80
# 29/01/2012      87
# 30/01/2012     219
#               ...
# 07/10/2012    1580
# 08/10/2012    1854
# 09/10/2012    4787
# 10/10/2012    3115
# 11/10/2012    3746
# 12/10/2012    3169
# 13/10/2012    1783
# 14/10/2012     587
# 15/10/2012    3292
# 16/10/2012    3739
# 17/10/2012    4098
# 18/10/2012    4671
# 19/10/2012    1313
# 20/10/2012    2011
# 21/10/2012    1277
# 22/10/2012    3650
# ...

# %%
# %matplotlib inline
#plot the graph for the 'Berri 1' path
fixed_df['Berri 1'].plot()

# %%
#plot the graph for all the bike paths and change graph dimensions to 15x10 inches
fixed_df.plot(figsize=(15, 10))
